# %% [markdown]
# ## MULTITHREADING AND MULTIPROCESSING

# %% [markdown]
# ## MEMORY MANAGEMENT

# %% [markdown]
# ## FLASK

# %% [markdown]
# ## STREAMLIT

# %% [markdown]
# ## STATISTICS

# %% [markdown]
# ## PROBABILITY

# %% [markdown]
# ## PDF

# %% [markdown]
# ## INFERENTIAL STATISTICS

# %% [markdown]
# ## FEATURE ENGINEERING

# %% [markdown]
# ## EDA

# %% [markdown]
# ## LINERA REGRESSION

# %% [markdown]
# ## RIDGE AND LASSO AND ELASTICNET ML ALGO

# %% [markdown]
# ## ML LIFECYCLE

# %% [markdown]
# ## LOGISTIC REGRESSION

# %% [markdown]
# ## SVM

# %% [markdown]
# ## NAIVE BAYES THEOREM

# %% [markdown]
# ## KNN

# %% [markdown]
# ## DECISION TREE CLASSIFIER AND REGRESSOR

# %% [markdown]
# ## RANDOM FOREST ML

# %% [markdown]
# ## ADABOOST ML

# %% [markdown]
# ## GRADIENT BOOST

# %% [markdown]
# ## XGBOOST

# %% [markdown]
# ## UNSUPERVISED ML

# %% [markdown]
# ## PCA

# %% [markdown]
# ## K MEANS CLUSTERING UNSUPERVISED ML

# %% [markdown]
# ## HIERARCHICAL CLUSTERING

# %% [markdown]
# ## DBSCAN CLUSTERING

# %% [markdown]
# ## SILHOUTTE CLUSTERING

# %% [markdown]
# ## ANOMALY DETECTION

# %% [markdown]
# ## DOCKERS

# %% [markdown]
# ## GIT

# %% [markdown]
# ## E2E ML WITH AWS,Azure Deploy

# %% [markdown]
# ## E2E MLOPS WITH ETL PIPELINES

# %% [markdown]
# ## MLFLOW DAGSHUB AND BENTOML LIFECYCLE

# %% [markdown]
# ## NLP

# %% [markdown]
# ## DL

# %% [markdown]
# ## E2E DL USING ANN

# %% [markdown]
# ## NLP WTH DL

# %% [markdown]
# ## RNN

# %% [markdown]
# ## E2E DL WITH RNN

# %% [markdown]
# ## LSTM AND GRU RNN

# %% [markdown]
# ## LSTM AND GRU E2E DL - PREDICT NEXT WORD

# %% [markdown]
# ## BIDIRECTIONAL RNN ARCHI

# %% [markdown]
# ## ENCODER DECODER - S2S ARCHI

# %% [markdown]
# ## ATTENTION MECHANISM - Seq2Seq Networks

# %% [markdown]
# ## TRANSFORMERS
