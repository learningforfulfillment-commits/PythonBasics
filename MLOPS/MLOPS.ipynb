# %% [markdown]
# ## FLASK

# %% [markdown]
# ## GIT

# %% [markdown]
# ## MLFLOW

# %% [markdown]
# ## MLFLOW TRACKING

# %% [markdown]
# ## DL WITH ANN MODEL BUILD INTEGARTE USING MLFLOW

# %% [markdown]
# ## DVC

# %% [markdown]
# ## DAGSHUB

# %% [markdown]
# ## E2E ML USING GIT, DVC,MLFLOW AND DAGSHUB

# %% [markdown]
# ## MLFLOW WITH AWS

# %% [markdown]
# ## DOCKERS

# %% [markdown]
# ## AIRFLOW

# %% [markdown]
# ## AIRFLOW ETL PIPELINE WITH POSTGRES AND API INTEGRATION IN ASTRO CLOUD AND AWS

# %% [markdown]
# ## E2E GITHUB USING DOCKER

# %% [markdown]
# ## HUGGING FACE AND TRANSFORMERS

# %% [markdown]
# ## AWS SAGEMAKER

# %% [markdown]
# ## GRAFANA

# %% [markdown]
# ## GENAI WITH AWS LLMOPS
